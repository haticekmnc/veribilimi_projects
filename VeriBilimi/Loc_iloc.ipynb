# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
plot = sns.load_dataset("exercise")
plot.head()
# Out:
#    Unnamed: 0  id     diet  pulse    time  kind
# 0           0   1  low fat     85   1 min  rest
# 1           1   1  low fat     85  15 min  rest
# 2           2   1  low fat     88  30 min  rest
# 3           3   2  low fat     90   1 min  rest
# 4           4   2  low fat     92  15 min  rest

# %%
plot["diet"].head()
type(plot["diet"].head())
# Out:
# pandas.core.series.Series

# %%
plot[["diet"]].head()
type(plot[["diet"]].head())
# Out:
# pandas.core.frame.DataFrame

# %%
plot.loc[:,~plot.columns.str.contains("diet")].head
# Out:
# <bound method NDFrame.head of     Unnamed: 0  id  pulse    time     kind
# 0            0   1     85   1 min     rest
# 1            1   1     85  15 min     rest
# 2            2   1     88  30 min     rest
# 3            3   2     90   1 min     rest
# 4            4   2     92  15 min     rest
# ..         ...  ..    ...     ...      ...
# 85          85  29    135  15 min  running
# 86          86  29    130  30 min  running
# 87          87  30     99   1 min  running
# 88          88  30    111  15 min  running
# 89          89  30    150  30 min  running
#
# [90 rows x 5 columns]>

# %%
plot.iloc[0:4]
# Out:
#    Unnamed: 0  id     diet  pulse    time  kind
# 0           0   1  low fat     85   1 min  rest
# 1           1   1  low fat     85  15 min  rest
# 2           2   1  low fat     88  30 min  rest
# 3           3   2  low fat     90   1 min  rest

# %%
plot.loc[0:4]
# Out:
#    Unnamed: 0  id     diet  pulse    time  kind
# 0           0   1  low fat     85   1 min  rest
# 1           1   1  low fat     85  15 min  rest
# 2           2   1  low fat     88  30 min  rest
# 3           3   2  low fat     90   1 min  rest
# 4           4   2  low fat     92  15 min  rest
